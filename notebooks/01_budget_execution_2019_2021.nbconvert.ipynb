# %% [markdown]
# # Budget Execution Analysis
#
# This notebook analyzes budget execution data from Carmen de Areco's transparency portal for years 2019-2025.

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
import os
from pathlib import Path
import glob

# Set up data paths
data_paths = [
    Path("../data/processed"),
    Path("../data/consolidated"),
    Path("../data/cleaned"),
    Path("../frontend/public/data/csv"),
    Path("../../data/processed"),
    Path("../../data/consolidated"),
    Path("../../frontend/public/data/charts")
]

# Find all budget-related CSV files
all_budget_files = []
for path in data_paths:
    if path.exists():
        all_budget_files.extend(list(path.rglob("*budget*csv")))
        all_budget_files.extend(list(path.rglob("*execution*csv")))
        all_budget_files.extend(list(path.rglob("*presupuesto*csv")))
        all_budget_files.extend(list(path.rglob("*ejecucion*csv")))

print(f"Found {len(all_budget_files)} budget/execution files")
# Out:
# Found 5 budget/execution files

# %%
# Load the most comprehensive budget execution data
df = None

# Look for consolidated budget execution data first
for file_path in all_budget_files:
    if 'consolidated' in str(file_path) or 'Budget_Execution' in str(file_path):
        df = pd.read_csv(file_path)
        print(f"Loaded data from: {file_path}")
        break

# If no consolidated data found, use the first available file
if df is None and all_budget_files:
    df = pd.read_csv(all_budget_files[0])
    print(f"Loaded data from: {all_budget_files[0]}")

# If no budget files found, create sample data
if df is None:
    print("No budget execution data found, creating sample data for demonstration")
    
    # Sample data for demonstration
    data = {
        'year': [2019, 2019, 2019, 2020, 2020, 2020, 2021, 2021, 2021, 2022, 2022, 2022],
        'sector': ['Educacion', 'Salud', 'Obras y Servicios Publicos', 
                  'Educacion', 'Salud', 'Obras y Servicios Publicos',
                  'Educacion', 'Salud', 'Obras y Servicios Publicos',
                  'Educacion', 'Salud', 'Obras y Servicios Publicos'],
        'budget': [1000000, 800000, 1200000, 1100000, 850000, 1300000, 1150000, 900000, 1350000, 1200000, 950000, 1400000],
        'executed': [950000, 780000, 1180000, 1050000, 820000, 1250000, 1100000, 880000, 1320000, 1180000, 920000, 1380000],
    }
    df = pd.DataFrame(data)

# Standardize column names
column_mapping = {
    'Presupuesto': 'budget',
    'Ejecutado': 'executed',
    'Año': 'year',
    'anio': 'year',
    'Ejercicio': 'year',
    'Sector': 'sector',
    'area': 'sector',
    'departamento': 'sector',
    'Monto_Presupuestado': 'budget',
    'Monto_Ejecutado': 'executed',
    'Porcentaje_Ejecucion': 'execution_percentage'
}

df = df.rename(columns=column_mapping)

# Convert columns to appropriate types
numeric_cols = ['budget', 'executed']
for col in numeric_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

if 'year' in df.columns:
    df['year'] = pd.to_numeric(df['year'], errors='coerce').astype('Int64')

print(f"Dataset shape: {df.shape}")
print(df.head())
print(f"\nColumns: {list(df.columns)}")
# Out:
# Loaded data from: ../data/processed/budget_execution_all_years.csv
# Dataset shape: (51, 37)
#   R.A.F.A.M. Hoja: 1 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n27/02/2025 14:03\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 31/12/2024 Ejercicio 2024\n:  \
# 0                              Apertura Programática
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#           Unnamed: 1        Unnamed: 2        Unnamed: 3  Unnamed: 4  \
# 0  Crédito\nAprobado  Modifica\nciones  Crédito\nVigente  Preventivo
# 1          Devengado         Percibido               NaN   Devengado
# 2          Devengado         Percibido               NaN   Devengado
# 3          Devengado         Percibido               NaN   Devengado
# 4          Devengado         Percibido               NaN   Devengado
#
#    Unnamed: 5            Unnamed: 6 Unnamed: 7           Unnamed: 8  \
# 0  Compromiso             Devengado     Pagado  Crédito\nDisponible
# 1      Pagado  Devengado\nno Pagado        NaN                  NaN
# 2      Pagado  Devengado\nno Pagado        NaN                  NaN
# 3      Pagado  Devengado\nno Pagado        NaN                  NaN
# 4      Pagado  Devengado\nno Pagado        NaN                  NaN
#
#                   Unnamed: 9  ...  \
# 0  Crédito Vig.\n- Devengado  ...
# 1                        NaN  ...
# 2                        NaN  ...
# 3                        NaN  ...
# 4                        NaN  ...
#
#   R.A.F.A.M. Hoja: 2 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n08/10/2024 11:01\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 30/09/2024 Ejercicio 2024\n:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   R.A.F.A.M. Hoja: 1 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n08/10/2024 11:01\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 30/09/2024 Ejercicio 2024\n:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    R.A.F.A.M. Hoja: 3 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n08/10/2024 11:01\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 30/09/2024 Ejercicio 2024\n:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   R.A.F.A.M. Hoja: 1 de 2\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/04/2025 13:13\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2025 al 31/03/2025 Ejercicio 2025\n:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   R.A.F.A.M. Hoja: 1 de 1\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/04/202513:05\nMunicipalidad de Del 02/01/2025 al 31/03/2025\nEjercicio 2025\nCarmen de Areco\n:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   R.A.F.A.M. Hoja: 2 de 2\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/04/2025 13:13\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2025 al 31/03/2025 Ejercicio 2025\n:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   R.A.F.A.M. Hoja: 1 de 1\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n27/02/202513:37\nMunicipalidad de Del 02/01/2024 al 31/12/2024\nEjercicio 2024\nCarmen de Areco\n:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   R.A.F.A.M. Hoja: 3 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/08/2024 12:58\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 30/06/2024 Ejercicio 2024\n:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   R.A.F.A.M. Hoja: 1 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/08/2024 12:58\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 30/06/2024 Ejercicio 2024\n:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   R.A.F.A.M. Hoja: 2 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/08/2024 12:58\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 30/06/2024 Ejercicio 2024\n:
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 37 columns]
#
# Columns: ['R.A.F.A.M. Hoja: 1 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n27/02/2025 14:03\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 31/12/2024 Ejercicio 2024\n:', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'source_file', 'year', 'quarter', 'Recursos', 'Gastos', 'R.A.F.A.M. Hoja: 2 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n27/02/2025 14:03\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 31/12/2024 Ejercicio 2024\n:', 'R.A.F.A.M. Hoja: 1 de 1\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n08/10/202410:56\nMunicipalidad de Del 02/01/2024 al 30/09/2024\nEjercicio 2024\nCarmen de Areco\n:', 'R.A.F.A.M. Hoja: 3 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n27/02/2025 14:03\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 31/12/2024 Ejercicio 2024\n:', 'R.A.F.A.M. Hoja: 1 de 1\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n10/07/202510:33\nMunicipalidad de Del 02/01/2025 al 30/06/2025\nEjercicio 2025\nCarmen de Areco\n:', 'R.A.F.A.M. Hoja: 1 de 1\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/08/202412:54\nMunicipalidad de Del 02/01/2024 al 30/06/2024\nEjercicio 2024\nCarmen de Areco\n:', 'R.A.F.A.M. Hoja: 1 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/08/2024 12:59\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 31/03/2024 Ejercicio 2024\n:', 'R.A.F.A.M. Hoja: 1 de 1\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/08/202412:55\nMunicipalidad de Del 02/01/2024 al 31/03/2024\nEjercicio 2024\nCarmen de Areco\n:', 'R.A.F.A.M. Hoja: 2 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/08/2024 12:59\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 31/03/2024 Ejercicio 2024\n:', 'R.A.F.A.M. Hoja: 2 de 2\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n10/07/2025 10:32\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2025 al 30/06/2025 Ejercicio 2025\n:', 'R.A.F.A.M. Hoja: 1 de 2\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n10/07/2025 10:32\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2025 al 30/06/2025 Ejercicio 2025\n:', 'R.A.F.A.M. Hoja: 3 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/08/2024 12:59\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 31/03/2024 Ejercicio 2024\n:', 'R.A.F.A.M. Hoja: 2 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n08/10/2024 11:01\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 30/09/2024 Ejercicio 2024\n:', 'R.A.F.A.M. Hoja: 1 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n08/10/2024 11:01\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 30/09/2024 Ejercicio 2024\n:', 'R.A.F.A.M. Hoja: 3 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n08/10/2024 11:01\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2024 al 30/09/2024 Ejercicio 2024\n:', 'R.A.F.A.M. Hoja: 1 de 2\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/04/2025 13:13\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2025 al 31/03/2025 Ejercicio 2025\n:', 'R.A.F.A.M. Hoja: 1 de 1\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/04/202513:05\nMunicipalidad de Del 02/01/2025 al 31/03/2025\nEjercicio 2025\nCarmen de Areco\n:', 'R.A.F.A.M. Hoja: 2 de 2\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/04/2025 13:13\n(CON PERSPECTIVA DE GÉNERO)\nMunicipalidad de\nCarmen de Areco Del 02/01/2025 al 31/03/2025 Ejercicio 2025\n:', 'R.A.F.A.M. Hoja: 1 de 1\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n27/02/202513:37\nMunicipalidad de Del 02/01/2024 al 31/12/2024\nEjercicio 2024\nCarmen de Areco\n:', 'R.A.F.A.M. Hoja: 3 de 3\nESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS\n26/08/2024 12:58\n(CON PERSPECTIVA DE ...

# %%
# Calculate execution percentage if not already present
if 'executed' in df.columns and 'budget' in df.columns:
    df['execution_percentage'] = np.where(df['budget'] != 0, (df['executed'] / df['budget']) * 100, 0)
    
# Create a bar chart showing budget vs execution by sector
if 'sector' in df.columns and 'budget' in df.columns and 'executed' in df.columns:
    fig = px.bar(df, 
                 x='sector', 
                 y=['budget', 'executed'], 
                 title="Budget vs Execution by Sector",
                 barmode='group',
                 labels={'value': 'Amount (ARS)', 'variable': 'Type'},
                 color_discrete_map={'budget': 'blue', 'executed': 'green'})

    # Add value labels on bars
    fig.update_traces(texttemplate='%{value:,.0f}', textposition='outside')

    fig.update_layout(
        yaxis_title="Amount (ARS)",
        xaxis_title="Sector",
        uniformtext_minsize=8,
        uniformtext_mode='hide'
    )

    fig.show()
else:
    print("Required columns for budget vs execution chart not found")
# Out:
# Required columns for budget vs execution chart not found

# %%
# Create a line chart showing budget execution trends over years
if 'year' in df.columns and 'budget' in df.columns and 'executed' in df.columns:
    # Group by year if multiple entries per year
    if 'sector' in df.columns:
        yearly_df = df.groupby(['year', 'sector']).agg({'budget': 'sum', 'executed': 'sum'}).reset_index()
        fig_trend = px.line(yearly_df, 
                            x='year', 
                            y=['budget', 'executed'], 
                            color='sector',
                            title="Budget Execution Trends by Sector",
                            labels={'value': 'Amount (ARS)', 'variable': 'Type'})
    else:
        yearly_df = df.groupby('year').agg({'budget': 'sum', 'executed': 'sum'}).reset_index()
        fig_trend = px.line(yearly_df, 
                            x='year', 
                            y=['budget', 'executed'], 
                            title="Budget Execution Trends",
                            labels={'value': 'Amount (ARS)', 'variable': 'Type'})

    fig_trend.update_layout(
        yaxis_title="Amount (ARS)",
        xaxis_title="Year",
        legend_title="Type"
    )

    fig_trend.show()
else:
    print("Required columns for trend analysis not found")
# Out:
# Required columns for trend analysis not found

# %%
# Create a scatter plot to show budget vs executed amounts
if 'budget' in df.columns and 'executed' in df.columns:
    color_col = 'sector' if 'sector' in df.columns else None
    size_col = 'budget' if len(df) < 100 else None  # Only use size for smaller datasets
    
    fig_scatter = px.scatter(df, 
                             x='budget', 
                             y='executed', 
                             color=color_col,
                             size=size_col,
                             hover_data=['year'] if 'year' in df.columns else [],
                             title="Budget vs Execution Amounts",
                             labels={'budget': 'Budget (ARS)', 'executed': 'Executed (ARS)'})

    # Add perfect execution line (y=x)
    max_val = max(df['budget'].max(), df['executed'].max())
    fig_scatter.add_shape(
        type='line',
        x0=0,
        x1=max_val,
        y0=0,
        y1=max_val,
        line=dict(color='red', width=2, dash='dash'),
        name='Perfect Execution',
        yref='y',
        xref='x'
    )

    fig_scatter.show()
else:
    print("Required columns for scatter plot not found")
# Out:
# Required columns for scatter plot not found

# %%
# Create a gauge chart for overall execution percentage
if 'executed' in df.columns and 'budget' in df.columns:
    overall_execution = (df['executed'].sum() / df['budget'].sum()) * 100 if df['budget'].sum() != 0 else 0

    fig_gauge = go.Figure(go.Indicator(
        domain = {'x': [0, 1], 'y': [0, 1]},
        value = overall_execution,
        mode = "gauge+number+delta",
        title = {'text': "Overall Budget Execution"},
        delta = {'reference': 100},
        gauge = {'axis': {'range': [None, 100]},
                 'bar': {'color': "darkblue"},
                 'steps': [
                     {'range': [0, 50], 'color': "lightgray"},
                     {'range': [50, 75], 'color': "gray"},
                     {'range': [75, 100], 'color': "darkgray"}],
                 'threshold': {'line': {'color': "red", 'width': 4},
                              'thickness': 0.75,
                              'value': overall_execution}}))

    fig_gauge.update_layout(height=400)
    fig_gauge.show()

    print(f"Overall execution rate: {overall_execution:.2f}%")
else:
    print("Required columns for gauge chart not found")
# Out:
# Required columns for gauge chart not found

# %%
# Summary statistics
print("Summary Statistics:")
if 'budget' in df.columns:
    print(f"- Total Budget: {df['budget'].sum():,.2f} ARS")
if 'executed' in df.columns:
    print(f"- Total Executed: {df['executed'].sum():,.2f} ARS")
if 'budget' in df.columns and 'executed' in df.columns and df['budget'].sum() != 0:
    overall_execution = (df['executed'].sum() / df['budget'].sum()) * 100
    print(f"- Overall Execution Rate: {overall_execution:.2f}%")
    
if 'sector' in df.columns and 'budget' in df.columns and 'executed' in df.columns:
    print(f"\nSector-wise Execution:")

    sector_summary = df.groupby('sector')[['budget', 'executed']].sum()
    sector_summary['execution_rate'] = np.where(sector_summary['budget'] != 0, 
                                                (sector_summary['executed'] / sector_summary['budget']) * 100, 
                                                0)
    sector_summary['execution_rate'] = sector_summary['execution_rate'].round(2)

    print(sector_summary)
else:
    print("\nSector-wise analysis not possible - missing required columns")
    
# Data completeness report
print(f"\nData Completeness Report:")
print(f"- Total records: {len(df)}")
for col in df.columns:
    non_null_count = df[col].notna().sum()
    completeness = (non_null_count / len(df)) * 100 if len(df) > 0 else 0
    print(f"- {col}: {completeness:.1f}% complete ({non_null_count}/{len(df)} records)")
# Out:
# Summary Statistics:
#
# Sector-wise analysis not possible - missing required columns
#
# Data Completeness Report:
# - Total records: 51
# - R.A.F.A.M. Hoja: 1 de 3
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 27/02/2025 14:03
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2024 al 31/12/2024 Ejercicio 2024
# :: 2.0% complete (1/51 records)
# - Unnamed: 1: 100.0% complete (51/51 records)
# - Unnamed: 2: 100.0% complete (51/51 records)
# - Unnamed: 3: 43.1% complete (22/51 records)
# - Unnamed: 4: 100.0% complete (51/51 records)
# - Unnamed: 5: 100.0% complete (51/51 records)
# - Unnamed: 6: 100.0% complete (51/51 records)
# - Unnamed: 7: 43.1% complete (22/51 records)
# - Unnamed: 8: 43.1% complete (22/51 records)
# - Unnamed: 9: 43.1% complete (22/51 records)
# - Unnamed: 10: 43.1% complete (22/51 records)
# - source_file: 100.0% complete (51/51 records)
# - year: 100.0% complete (51/51 records)
# - quarter: 100.0% complete (51/51 records)
# - Recursos: 56.9% complete (29/51 records)
# - Gastos: 56.9% complete (29/51 records)
# - R.A.F.A.M. Hoja: 2 de 3
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 27/02/2025 14:03
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2024 al 31/12/2024 Ejercicio 2024
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 1 de 1
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 08/10/202410:56
# Municipalidad de Del 02/01/2024 al 30/09/2024
# Ejercicio 2024
# Carmen de Areco
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 3 de 3
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 27/02/2025 14:03
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2024 al 31/12/2024 Ejercicio 2024
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 1 de 1
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 10/07/202510:33
# Municipalidad de Del 02/01/2025 al 30/06/2025
# Ejercicio 2025
# Carmen de Areco
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 1 de 1
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 26/08/202412:54
# Municipalidad de Del 02/01/2024 al 30/06/2024
# Ejercicio 2024
# Carmen de Areco
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 1 de 3
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 26/08/2024 12:59
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2024 al 31/03/2024 Ejercicio 2024
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 1 de 1
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 26/08/202412:55
# Municipalidad de Del 02/01/2024 al 31/03/2024
# Ejercicio 2024
# Carmen de Areco
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 2 de 3
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 26/08/2024 12:59
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2024 al 31/03/2024 Ejercicio 2024
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 2 de 2
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 10/07/2025 10:32
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2025 al 30/06/2025 Ejercicio 2025
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 1 de 2
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 10/07/2025 10:32
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2025 al 30/06/2025 Ejercicio 2025
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 3 de 3
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 26/08/2024 12:59
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2024 al 31/03/2024 Ejercicio 2024
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 2 de 3
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 08/10/2024 11:01
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2024 al 30/09/2024 Ejercicio 2024
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 1 de 3
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 08/10/2024 11:01
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2024 al 30/09/2024 Ejercicio 2024
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 3 de 3
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 08/10/2024 11:01
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2024 al 30/09/2024 Ejercicio 2024
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 1 de 2
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 26/04/2025 13:13
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2025 al 31/03/2025 Ejercicio 2025
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 1 de 1
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 26/04/202513:05
# Municipalidad de Del 02/01/2025 al 31/03/2025
# Ejercicio 2025
# Carmen de Areco
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 2 de 2
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 26/04/2025 13:13
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2025 al 31/03/2025 Ejercicio 2025
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 1 de 1
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 27/02/202513:37
# Municipalidad de Del 02/01/2024 al 31/12/2024
# Ejercicio 2024
# Carmen de Areco
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 3 de 3
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 26/08/2024 12:58
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2024 al 30/06/2024 Ejercicio 2024
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 1 de 3
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 26/08/2024 12:58
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2024 al 30/06/2024 Ejercicio 2024
# :: 2.0% complete (1/51 records)
# - R.A.F.A.M. Hoja: 2 de 3
# ESTADO DE EJECUCION DEL PRESUPUESTO DE GASTOS
# 26/08/2024 12:58
# (CON PERSPECTIVA DE GÉNERO)
# Municipalidad de
# Carmen de Areco Del 02/01/2024 al 30/06/2024 Ejercicio 2024
# :: 2.0% complete (1/51 records)
